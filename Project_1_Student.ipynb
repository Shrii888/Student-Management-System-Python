# %% [markdown]
# # STUDENT MANAGEMENT SYSTEM

# %% [markdown]
# ![ChatGPT Image Sep 26, 2026, 01_27_05 AM.png](attachment:1731f191-3474-4225-8fb9-eb791c3ac70a.png)

# %%
import json

try:
    with open("students.json", "r") as file:
        students = json.load(file)
except FileNotFoundError:
    students = []

print(students)
# Out:
# [{'id': 101, 'name': 'Shriya Verma', 'age': 28, 'course': 'B.com', 'marks': 98.0}]

# %%
def save_records():
    with open("students.json", "w") as file:
        json.dump(students, file, indent=4)

# %%
save_records()

# %%
def add_students():
    student_id = int(input("Enter student's id :"))
    name = input("Enter name :")
    age = int(input("Enter age :"))
    course = input("Enter Course name :")
    marks = float(input("Enter marks :"))

    student = {
        "id": student_id,
        "name": name,
        "age": age,
        "course": course,
        "marks": marks
    }

    students.append(student)
    save_records()

# %%
save_records()

# %%
add_students()
# Out:
# Enter student's id : 101
# Enter name : Shriya Verma
# Enter age : 28
# Enter Course name : B.com
# Enter marks : 98

# %%
print(students)
# Out:
# [{'id': 101, 'name': 'Shriya Verma', 'age': 28, 'course': 'B.com', 'marks': 98.0}]

# %%
add_students()
# Out:
# Enter student's id : 103
# Enter name : Tejasswi Singh
# Enter age : 20
# Enter Course name : B.sc
# Enter marks : 97

# %%
add_students()
# Out:
# Enter student's id : 102
# Enter name : Nancy Tyagi
# Enter age : 20
# Enter Course name : B.com
# Enter marks : 98

# %%
add_students()
# Out:
# Enter student's id : 104
# Enter name : Riya Rai
# Enter age : 29
# Enter Course name : M.com
# Enter marks : 75

# %%
add_students()
# Out:
# Enter student's id : 105
# Enter name : Mohit Singh
# Enter age : 25
# Enter Course name : BA
# Enter marks : 88

# %%
add_students()
# Out:
# Enter student's id : 106
# Enter name : Parul Singh
# Enter age : 30
# Enter Course name : B.Tech
# Enter marks : 78

# %%
add_students()
# Out:
# Enter student's id : 107
# Enter name : Rajveer Mehta
# Enter age : 24
# Enter Course name : BA
# Enter marks : 76

# %%
add_students()
# Out:
# Enter student's id : 108
# Enter name : Yashi Gupta
# Enter age : 25
# Enter Course name : BBA
# Enter marks : 67

# %%
add_students()
# Out:
# Enter student's id : 109
# Enter name : Rishabh Yadav
# Enter age : 25
# Enter Course name : B.Tech
# Enter marks : 79

# %%
add_students()
# Out:
# Enter student's id : 110
# Enter name : Hafsa Khan
# Enter age : 20
# Enter Course name : LLB
# Enter marks : 69

# %%
def display_students():
    for student in students:
        print(
            student["id"],
            student["name"],
            student["age"],
            student["course"],
            student["marks"]
        )

# %%
display_students()
# Out:
# 101 Shriya Verma 28 B.com 98.0
# 102 Nancy Tyagi 20 B.com 98.0
# 103 Tejasswi Singh 20 B.sc 97.0
# 104 Riya Rai 29 M.com 75.0
# 105 Mohit Singh 25 BA 88.0
# 106 Parul Singh 30 B.Tech 78.0
# 107 Rajveer Mehta 24 BA 76.0
# 108 Yashi Gupta 25 BBA 67.0
# 109 Rishabh Yadav 25 B.Tech 79.0
# 110 Hafsa Khan 20 LLB 69.0

# %%
def search_student():
    student_id = int(input("Enter id to find the student :"))
    
    for student in students:
        if student["id"]== student_id:
            print(" Student Found ")
            print("ID :",student["id"])
            print("Name : ", student["name"])
            print("Age :",student["age"])
            print("Course :", student["course"])
            print("Marks :", student["marks"])
            return
    print("Student not found !")

# %%
search_student()
# Out:
# Enter id to find the student : 108
#  Student Found
# ID : 108
# Name :  Yashi Gupta
# Age : 25
# Course : BBA
# Marks : 67.0

# %%
search_student()
# Out:
# Enter id to find the student : 111
# Student not found !

# %%
search_student()
# Out:
# Enter id to find the student : 103
#  Student Found
# ID : 103
# Name :  Tejasswi Singh
# Age : 20
# Course : B.sc
# Marks : 97.0

# %%
search_student()
# Out:
# Enter id to find the student : 117
# Student not found !

# %%
def update_student():
    student_id = int(input("Enter the id to update records: "))

    for student in students:
        if student["id"] == student_id:
            print("Student found!")
            print("1. Name")
            print("2. Age")
            print("3. Course")
            print("4. Marks")

            choice = int(input("Enter your choice: "))

            if choice == 1:
                student["name"] = input("Enter new name: ")

            elif choice == 2:
                student["age"] = int(input("Enter new age: "))

            elif choice == 3:
                student["course"] = input("Enter new course: ")

            elif choice == 4:
                student["marks"] = float(input("Enter new marks: "))

            else:
                print("Invalid choice!")
                return

            save_records()
            print("Student record updated successfully!")
            return

    print("Student not found!")

# %%
update_student()
# Out:
# Enter the id to update records:  103
# Student found!
# 1. Name
# 2. Age
# 3. Course
# 4. Marks
# Enter your choice:  4
# Enter new marks:  100
# Student record updated successfully!

# %%
update_student()
# Out:
# Enter the id to update records:  101
# Student found!
# 1. Name
# 2. Age
# 3. Course
# 4. Marks
# Enter your choice:  4
# Enter new marks:  100
# Student record updated successfully!

# %%
update_student()
# Out:
# Enter the id to update records:  1
# Student not found!

# %%
update_student()
# Out:
# Enter the id to update records:  101
# Student found!
# 1. Name
# 2. Age
# 3. Course
# 4. Marks
# Enter your choice:  1
# Enter new name:  Mehak Mehta
# Student record updated successfully!

# %%
update_student()
# Out:
# Enter the id to update records:  111
# Student not found!

# %%
def delete_student():
    student_id = int(input("Enter Student ID to delete: "))

    for student in students:
        if student["id"] == student_id:
            students.remove(student)
            save_records()
            print("Student deleted successfully!")
            return

    print("Student not found!")

# %%
delete_student()
# Out:
# Enter Student ID to delete:  103
# Student deleted successfully!

# %%
delete_student()
# Out:
# Enter Student ID to delete:  111
# Student not found!

# %%
def calculate_avg(): 
    if len(students)== 0:
        print("No student records avaialble!")
        return
    total_marks = 0 
    for student in students:
        total_marks = total_marks + student["marks"]
    average = total_marks/len(students)
    print(" Average Marks :", round(average,2 ))

# %%
calculate_avg()
# Out:
#  Average Marks : 81.11

# %%
while True:
    print("\n====================================")
    print("       STUDENT MANAGEMENT SYSTEM")
    print("====================================")
    print("1. Add Student")
    print("2. Display Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Calculate Average Marks")
    print("7. Save Records")
    print("8. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        add_students()

    elif choice == 2:
        display_students()

    elif choice == 3:
        search_student()

    elif choice == 4:
        update_student()

    elif choice == 5:
        delete_student()

    elif choice == 6:
        calculate_avg()

    elif choice == 7:
        save_records()
        print("Records saved successfully!")

    elif choice == 8:
        print("Thank you for using Student Management System!")
        break

    else:
        print("Invalid choice! Please enter a number between 1 and 8.")
# Out:
# ...
#        STUDENT MANAGEMENT SYSTEM
# ...
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Calculate Average Marks
# 7. Save Records
# 8. Exit
# Enter your choice:  1
# Enter student's id : 112
# Enter name : Neelam Verma
# Enter age : 22
# Enter Course name : B.com
# Enter marks : 72
# ...
#        STUDENT MANAGEMENT SYSTEM
# ...
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Calculate Average Marks
# 7. Save Records
# 8. Exit
# Enter your choice:  3
# Enter id to find the student : 111
#  Student Found
# ID : 111
# Name :  Mohit Sharma
# Age : 27
# Course : BCA
# Marks : 79.0
#
# ...
#        STUDENT MANAGEMENT SYSTEM
# ...
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Calculate Average Marks
# 7. Save Records
# 8. Exit
# Enter your choice:  4
# Enter the id to update records:  112
# Student found!
# 1. Name
# 2. Age
# 3. Course
# 4. Marks
# ...
